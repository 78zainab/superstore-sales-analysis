# %% [markdown]
# ### level 12: Visualization

# %%
# re run the previous file: 
# %run Analysis.ipynb
# Out:
# Shape: (5901, 23)
# Index(['Row ID+O6G3A1:R6', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Profit', 'Returns', 'Payment Mode', 'ind1',
#        'ind2'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Row ID+O6G3A1:R6  5901 non-null   int64
#  1   Order ID          5901 non-null   object
#  2   Order Date        5901 non-null   object
#  3   Ship Date         5901 non-null   object
#  4   Ship Mode         5901 non-null   object
#  5   Customer ID       5901 non-null   object
#  6   Customer Name     5901 non-null   object
#  7   Segment           5901 non-null   object
# ...

# %% [markdown]
# ### Single Metric Comparision

# %%
## sales by region, which region has the highest sales
sales_by_region.plot(kind='bar', title='Sales by Region', xlabel='Region', ylabel='Sales', color='green', legend=True, figsize=(3, 3))
# Out:
# <Axes: title={'center': 'Sales by Region'}, xlabel='Region', ylabel='Sales'>

# %%
sales_by_region.plot(kind='pie', title='Sales by Region', xlabel='', ylabel='', figsize=(3, 3), autopct='%1.1f%%',  startangle=90)
# West is about 1/3 of total sales
# Out:
# <Axes: title={'center': 'Sales by Region'}>

# %%
## shipping mode, which shipping mode is the most used?
ship_mode.plot(kind='bar', title='Most Used Shipping Mode', xlabel='Shipping Mode', ylabel='Count', color='blue', legend=True, figsize=(3, 3))
# Out:
# <Axes: title={'center': 'Most Used Shipping Mode'}, xlabel='Shipping Mode', ylabel='Count'>

# %%
ship_mode.plot(kind='pie', title='Most Used Shipping Mode', ylabel='', figsize=(3, 3), autopct='%1.1f%%', startangle=90)
# Out:
# <Axes: title={'center': 'Most Used Shipping Mode'}>

# %%
## shipping by year, how did the shipping volume change over the years?
shipping_by_year.plot(kind='bar', title='Shipping Volume by Year', xlabel='Year', ylabel='Count', color='orange', legend=True, figsize=(3, 3))
# Out:
# <Axes: title={'center': 'Shipping Volume by Year'}, xlabel='Year', ylabel='Count'>

# %%
shipping_by_year.plot(kind='line', title='Shipping Volume by Year', xlabel='Year', ylabel='Count', color='orange', legend=True, figsize=(3, 3))
# Out:
# <Axes: title={'center': 'Shipping Volume by Year'}, xlabel='Year', ylabel='Count'>

# %%
shipping_by_month.plot(kind='line', title='Shipping Volume by Month', xlabel='Month', ylabel='Count', color='purple', legend=True, figsize=(4, 3))
# Out:
# <Axes: title={'center': 'Shipping Volume by Month'}, xlabel='Month', ylabel='Count'>

# %%
shipping_by_date.plot(kind='line', title='Shipping Volume by Date', xlabel='Date', ylabel='Count', color='brown', figsize=(6, 4))
# Out:
# <Axes: title={'center': 'Shipping Volume by Date'}, xlabel='Date', ylabel='Count'>

# %% [markdown]
# ### Comparing two metrices

# %%
region_metrics.plot(kind='line', title='Sales and Profit by Region', xlabel='Region', ylabel='Sales and Profit', color=['green', 'orange'], figsize=(6, 6))
# Out:
# <Axes: title={'center': 'Sales and Profit by Region'}, xlabel='Region', ylabel='Sales and Profit'>

# %%
region_metrics.plot(kind='bar', title='Sales and Profit by Region', xlabel='Region', ylabel='Sales and Profit', color=['green', 'orange'], figsize=(6, 6))
# Out:
# <Axes: title={'center': 'Sales and Profit by Region'}, xlabel='Region', ylabel='Sales and Profit'>

# %%
category_metrics.plot(kind='bar', title='Sales and Profit by Category', xlabel='Category', ylabel='Sales and Profit', color=['green', 'orange'], figsize=(6, 6))
# Out:
# <Axes: title={'center': 'Sales and Profit by Category'}, xlabel='Category', ylabel='Sales and Profit'>

# %%
## which category has the highest sales and profits?
category_metrics.plot(kind='bar', title='Sales and Profit by Category', xlabel='Category', ylabel='Sales and Profit', color=['green', 'orange'], figsize=(3, 3))
category_metrics.plot(kind='barh', title='Sales and Profit by Category', xlabel='Sales and Profit', ylabel='Category', color=['green', 'orange'], figsize=(3, 3))
# Out:
# <Axes: title={'center': 'Sales and Profit by Category'}, xlabel='Sales and Profit', ylabel='Category'>

# %%
## how sales and profit changed over the years?
yearly_metrics.plot(kind='line', title='Sales and Profit by Year', xlabel='Year', ylabel='Sales and Profit', color=['green', 'orange'], figsize=(4, 3))
# Out:
# <Axes: title={'center': 'Sales and Profit by Year'}, xlabel='Year', ylabel='Sales and Profit'>

# %% [markdown]
# ### Trend Charts

# %%
## how shipping volume changed over the years?
shipping_by_year.plot(kind='line', title='Shipping Volume by Year', xlabel='Year', ylabel='Shipping Volume', color='blue', figsize=(3, 3))
# Out:
# <Axes: title={'center': 'Shipping Volume by Year'}, xlabel='Year', ylabel='Shipping Volume'>

# %%
## How did sales vary month by month?
monthly_metrics.plot(
    kind="line",
    title="Monthly Sales and Profit",
    figsize=(3,3), 
    xlabel="Month",
    ylabel="Sales and Profit",
)
# Out:
# <Axes: title={'center': 'Monthly Sales and Profit'}, xlabel='Month', ylabel='Sales and Profit'>

# %%
yearly_metrics.plot(
    kind="line",
    title="Yearly Sales and Profit",
    figsize=(3,3),
    xlabel="Year",
    ylabel="Sales and Profit",
)
# Out:
# <Axes: title={'center': 'Yearly Sales and Profit'}, xlabel='Year', ylabel='Sales and Profit'>

# %%
yearly_metrics.index = yearly_metrics.index.astype(str)

# %%
yearly_metrics.plot(
    kind="line",
    title="Yearly Sales and Profit",
    figsize=(3,3)
)
# Out:
# <Axes: title={'center': 'Yearly Sales and Profit'}, xlabel='Order Date'>
